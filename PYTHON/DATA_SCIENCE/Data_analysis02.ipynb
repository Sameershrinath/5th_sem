# %% [markdown]
# ## **Black Friday Data Analysis**

# %%
import pandas as pd 
df=pd.read_csv("./Dataset/BlackFriday.csv")

# %%
df.shape
# Out:
# (537577, 12)

# %%
df.head(2)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200

# %%
df.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            166986
# Product_Category_3            373299
# Purchase                           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537577 entries, 0 to 537576
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     537577 non-null  int64
#  1   Product_ID                  537577 non-null  object
#  2   Gender                      537577 non-null  object
#  3   Age                         537577 non-null  object
#  4   Occupation                  537577 non-null  int64
#  5   City_Category               537577 non-null  object
#  6   Stay_In_Current_City_Years  537577 non-null  object
#  7   Marital_Status              537577 non-null  int64
#  8   Product_Category_1          537577 non-null  int64
#  9   Product_Category_2          370591 non-null  float64
#  10  Product_Category_3          164278 non-null  float64
#  11  Purchase                    537577 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %% [markdown]
# Handling the null value

# %%
df.drop("Product_Category_2",axis=1,inplace=True)
df.drop("Product_Category_3",axis=1,inplace=True)

# %%
df.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# dtype: int64

# %% [markdown]
# Analysis of column

# %%
df.User_ID.nunique()
# Out:
# 5891

# %%
df.User_ID.value_counts()[0:10].plot(kind='bar')
# Out:
# <Axes: xlabel='User_ID'>

# %%
df.nunique()
# Out:
# User_ID                        5891
# Product_ID                     3623
# Gender                            2
# Age                               7
# Occupation                       21
# City_Category                     3
# Stay_In_Current_City_Years        5
# Marital_Status                    2
# Product_Category_1               18
# Purchase                      17959
# dtype: int64

# %% [markdown]
# Gender Analysis

# %%
df.Gender.value_counts().plot(kind='pie',autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %%
df_male=df[df["Gender"]=="M"]
df_female=df[df["Gender"]=="F"]

# %%
df.groupby("Gender")["Purchase"].sum().plot(kind="pie",autopct="%.2f")
# Out:
# <Axes: ylabel='Purchase'>

# %%
df.groupby("Gender")["Purchase"].mean().plot(kind="pie",autopct="%.2f")

# It is showing that male and female are spending nearly same
# Out:
# <Axes: ylabel='Purchase'>

# %% [markdown]
# Age and Maritial Status Analysis

# %%
df.groupby("Age").size().plot(kind="bar",figsize=(12,6),title="Age Group count")
# Out:
# <Axes: title={'center': 'Age Group count'}, xlabel='Age'>

# %%
df.groupby("Age")["Purchase"].sum().plot(kind="bar",figsize=(12,4),title="Age group total Spend")
# Out:
# <Axes: title={'center': 'Age group total Spend'}, xlabel='Age'>

# %%
df.groupby("Age")["Purchase"].mean().plot(kind="bar",figsize=(12,4),title="Age Group average spend")
# Out:
# <Axes: title={'center': 'Age Group average spend'}, xlabel='Age'>

# %%
df.groupby("Age")["Purchase"].mean().plot(kind="pie",autopct="%.1f",figsize=(12,4),title="Age Group average spend")
# Out:
# <Axes: title={'center': 'Age Group average spend'}, ylabel='Purchase'>

# %%
df.Purchase.sum()
# Out:
# 5017668378

# %% [markdown]
# Muti Column Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(hue="Gender",x="Age",data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(hue="Gender",x="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(hue="Age",x="Marital_Status",data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
df.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969

# %%
sns.countplot(df,x="Stay_In_Current_City_Years")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(df,x="Stay_In_Current_City_Years",hue="Gender")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(df,x="Stay_In_Current_City_Years",hue="Gender")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
df.groupby("Stay_In_Current_City_Years")["Purchase"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
df.groupby("Occupation")["Purchase"].sum().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby("Occupation")["Purchase"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(data=df,x="Occupation",hue="Gender")
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>
