# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("./german_credit_data.csv",index_col=False)

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.sample(10)
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 965         965   26  female    2     own             NaN         moderate
# 312         312   26  female    2     own          little             rich
# 438         438   65    male    0     own          little           little
# 517         517   23  female    2    rent          little              NaN
# 728         728   59  female    2    rent          little         moderate
# 978         978   47    male    1     own          little              NaN
# 945         945   30  female    2     own      quite rich         moderate
# 724         724   21  female    2    rent          little              NaN
# 422         422   47    male    1     own          little         moderate
# 679         679   26  female    2     own          little              NaN
#
#      Credit amount  Duration              Purpose  Risk
# 965           1715        30             radio/TV  good
# 312           3749        24  furniture/equipment  good
# 438           3394        42              repairs  good
# 517           7127        36  furniture/equipment   bad
# 728           6416        48             business   bad
# 978           2538        24                  car   bad
# 945           8358        48                  car  good
# 724           2570        27                  car   bad
# 422            958        12                  car  good
# 679           1453        18             radio/TV  good

# %%
df.describe()
# Out:
#         Unnamed: 0          Age          Job  Credit amount     Duration
# count  1000.000000  1000.000000  1000.000000    1000.000000  1000.000000
# mean    499.500000    35.546000     1.904000    3271.258000    20.903000
# std     288.819436    11.375469     0.653614    2822.736876    12.058814
# min       0.000000    19.000000     0.000000     250.000000     4.000000
# 25%     249.750000    27.000000     2.000000    1365.500000    12.000000
# 50%     499.500000    33.000000     2.000000    2319.500000    18.000000
# 75%     749.250000    42.000000     2.000000    3972.250000    24.000000
# max     999.000000    75.000000     3.000000   18424.000000    72.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1000 non-null   int64
#  1   Age               1000 non-null   int64
#  2   Sex               1000 non-null   object
#  3   Job               1000 non-null   int64
#  4   Housing           1000 non-null   object
#  5   Saving accounts   817 non-null    object
#  6   Checking account  606 non-null    object
#  7   Credit amount     1000 non-null   int64
#  8   Duration          1000 non-null   int64
#  9   Purpose           1000 non-null   object
#  10  Risk              1000 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 86.1+ KB

# %%
df.nunique()
# Out:
# Unnamed: 0          1000
# Age                   53
# Sex                    2
# Job                    4
# Housing                3
# Saving accounts        4
# Checking account       3
# Credit amount        921
# Duration              33
# Purpose                8
# Risk                   2
# dtype: int64

# %%
sns.countplot(x=df["Risk"], data=df)
plt.title('Count Plot of Risk')
plt.show()

# %%
df_good=df[df["Risk"]=="good"]
df_bad=df[df["Risk"]=="bad"]

# %%
date_int = ["Purpose", 'Sex']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(df[date_int[0]], df[date_int[1]]).style.background_gradient(cmap = cm)
# Out:
# <style type="text/css">
# #T_9ca19_row0_col0 {
#   background-color: #c1dfc1;
#   color: #000000;
# }
# #T_9ca19_row0_col1 {
#   background-color: #a4d0a4;
#   color: #000000;
# }
# #T_9ca19_row1_col0, #T_9ca19_row1_col1 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_9ca19_row2_col0 {
#   background-color: #e3efe3;
#   color: #000000;
# }
# #T_9ca19_row2_col1, #T_9ca19_row7_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_9ca19_row3_col0 {
#   background-color: #b4d8b4;
#   color: #000000;
# }
# #T_9ca19_row3_col1 {
#   background-color: #cee5ce;
#   color: #000000;
# }
# #T_9ca19_row4_col0 {
#   background-color: #349934;
#   color: #f1f1f1;
# }
# #T_9ca19_row4_col1 {
#   background-color: #86c286;
#   color: #000000;
# }
# #T_9ca19_row5_col0 {
#   background-color: #178b17;
#   color: #f1f1f1;
# }
# #T_9ca19_row5_col1 {
#   background-color: #2f972f;
#   color: #f1f1f1;
# }
# #T_9ca19_row6_col0 {
#   background-color: #e6f1e6;
#   color: #000000;
# }
# #T_9ca19_row6_col1 {
#   background-color: #e0eee0;
#   color: #000000;
# }
# #T_9ca19_row7_col1 {
#   background-color: #e8f2e8;
#   color: #000000;
# }
# </style>
# <table id="T_9ca19">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_9ca19_level0_col0" class="col_heading level0 col0" >female</th>
#       <th id="T_9ca19_level0_col1" class="col_heading level0 col1" >male</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Purpose</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ca19_level0_row0" class="row_heading level0 row0" >business</th>
#       <td id="T_9ca19_row0_col0" class="data row0 col0" >19</td>
#       <td id="T_9ca19_row0_col1" class="data row0 col1" >78</td>
#     </tr>
#     <tr>
#       <th id="T_9ca19_level0_row1" class="row_heading level0 row1" >car</th>
#       <td id="T_9ca19_row1_col0" class="data row1 col0" >94</td>
#       <td id="T_9ca19_row1_col1" class="data row1 col1" >243</td>
#     </tr>
#     <tr>
#       <th id="T_9ca19_level0_row2" class="row_heading level0 row2" >domestic appliances</th>
#       <td id="T_9ca19_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_9ca19_row2_col1" class="data row2 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_9ca19_level0_row3" class="row_heading level0 row3" >education</th>
#       <td id="T_9ca19_row3_col0" class="data row3 col0" >24</td>
#       <td id="T_9ca19_row3_col1" class="data row3 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_9ca19_level0_row4" class="row_heading level0 row4" >furniture/equipment</th>
#       <td id="T_9ca19_row4_col0" class="data row4 col0" >74</td>
#       <td id="T_9ca19_row4_col1" class="data row4 col1" >107</td>
#     </tr>
#     <tr>
#       <th id="T_9ca19_level0_row5" class="row_heading level0 row5" >radio/TV</th>
#       <td id="T_9ca19_row5_col0" class="data row5 col0" >85</td>
#       <td id="T_9ca19_row5_col1" class="data row5 col1" >195</td>
#     </tr>
#     <tr>
#       <th id="T_9ca19_level0_row6" class="row_heading level0 row6" >repairs</th>
#       <td id="T_9ca19_row6_col0" class="data row6 col0" >5</td>
#       <td id="T_9ca19_row6_col1" class="data row6 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_9ca19_level0_row7" class="row_heading level0 row7" >vacation/others</th>
#       <td id="T_9ca19_row7_col0" class="data row7 col0" >3</td>
#       <td id="T_9ca19_row7_col1" class="data row7 col1" >9</td>
#     </tr>
#   </tbody>
# </table>

# %%
#Let's look the Credit Amount column
interval = (18, 25, 35, 60, 120)

cats = ['Student', 'Young', 'Adult', 'Senior']
df["Age_cat"] = pd.cut(df.Age, interval, labels=cats)

# %%
print("Purpose : ",df.Purpose.unique())
print("Sex : ",df.Sex.unique())
print("Housing : ",df.Housing.unique())
print("Saving accounts : ",df['Saving accounts'].unique())
print("Risk : ",df['Risk'].unique())
print("Checking account : ",df['Checking account'].unique())
print("Aget_cat : ",df['Age_cat'].unique())
# Out:
# Purpose :  ['radio/TV' 'education' 'furniture/equipment' 'car' 'business'
#  'domestic appliances' 'repairs' 'vacation/others']
# Sex :  ['male' 'female']
# Housing :  ['own' 'free' 'rent']
# Saving accounts :  [nan 'little' 'quite rich' 'rich' 'moderate']
# Risk :  ['good' 'bad']
# Checking account :  ['little' 'moderate' nan 'rich']
# Aget_cat :  ['Senior', 'Student', 'Adult', 'Young']
# Categories (4, object): ['Student' < 'Young' < 'Adult' < 'Senior']

# %%
df['Saving accounts'] = df['Saving accounts'].fillna('no_inf')
df['Checking account'] = df['Checking account'].fillna('no_inf')

# %%
#Purpose to Dummies Variable
df = df.merge(pd.get_dummies(df.Purpose, drop_first=True, prefix='Purpose'), left_index=True, right_index=True)
#Sex feature in dummies
df = df.merge(pd.get_dummies(df.Sex, drop_first=True, prefix='Sex'), left_index=True, right_index=True)
# Housing get dummies
df = df.merge(pd.get_dummies(df.Housing, drop_first=True, prefix='Housing'), left_index=True, right_index=True)
# Housing get Saving Accounts
df = df.merge(pd.get_dummies(df["Saving accounts"], drop_first=True, prefix='Savings'), left_index=True, right_index=True)
# Housing get Risk
df = df.merge(pd.get_dummies(df.Risk, prefix='Risk'), left_index=True, right_index=True)
# Housing get Checking Account
df = df.merge(pd.get_dummies(df["Checking account"], drop_first=True, prefix='Check'), left_index=True, right_index=True)
# Housing get Age categorical
df = df.merge(pd.get_dummies(df["Age_cat"], drop_first=True, prefix='Age_cat'), left_index=True, right_index=True)

# %%
df.head()
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own          no_inf           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little           no_inf
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose  ... Savings_quite rich  \
# 0           1169         6             radio/TV  ...              False
# 1           5951        48             radio/TV  ...              False
# 2           2096        12            education  ...              False
# 3           7882        42  furniture/equipment  ...              False
# 4           4870        24                  car  ...              False
#
#   Savings_rich  Risk_bad  Risk_good  Check_moderate  Check_no_inf  Check_rich  \
# 0        False     False       True           False         False       False
# 1        False      True      False            True         False       False
# 2        False     False       True           False          True       False
# 3        False     False       True           False         False       False
# 4        False      True      False           False         False       False
#
#    Age_cat_Young  Age_cat_Adult  Age_cat_Senior
# 0          False          False            True
# 1          False          False           False
# 2          False           True           False
# 3          False           True           False
# 4          False           True           False
#
# [5 rows x 34 columns]

# %%
#Excluding the missing columns
del df["Saving accounts"]
del df["Checking account"]
del df["Purpose"]
del df["Sex"]
del df["Housing"]
del df["Age_cat"]
del df["Risk"]
del df['Risk_good']

# %%
df.head()
# Out:
#    Unnamed: 0  Age  Job  Credit amount  Duration  Purpose_car  \
# 0           0   67    2           1169         6        False
# 1           1   22    2           5951        48        False
# 2           2   49    1           2096        12        False
# 3           3   45    2           7882        42        False
# 4           4   53    2           4870        24         True
#
#    Purpose_domestic appliances  Purpose_education  \
# 0                        False              False
# 1                        False              False
# 2                        False               True
# 3                        False              False
# 4                        False              False
#
#    Purpose_furniture/equipment  Purpose_radio/TV  ...  Savings_no_inf  \
# 0                        False              True  ...            True
# 1                        False              True  ...           False
# 2                        False             False  ...           False
# 3                         True             False  ...           False
# 4                        False             False  ...           False
#
#    Savings_quite rich  Savings_rich  Risk_bad  Check_moderate  Check_no_inf  \
# 0               False         False     False           False         False
# 1               False         False      True            True         False
# 2               False         False     False           False          True
# 3               False         False     False           False         False
# 4               False         False      True           False         False
#
#    Check_rich  Age_cat_Young  Age_cat_Adult  Age_cat_Senior
# 0       False          False          False            True
# 1       False          False          False           False
# 2       False          False           True           False
# 3       False          False           True           False
# 4       False          False           True           False
#
# [5 rows x 26 columns]

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df.astype(float).corr(),linewidths=0.1,vmax=1.0, 
            square=True,  linecolor='white', annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split, KFold, cross_val_score # to split the data
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, fbeta_score #To evaluate our model

from sklearn.model_selection import GridSearchCV

# Algorithmns models to be compared
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from xgboost import XGBClassifier

# %%
#Creating the X and y variables
X = df.drop('Risk_bad', axis=1).values
y = df["Risk_bad"].values

# Spliting X and y into train and test version
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=42)

# %%
# to feed the random state
seed = 7

# prepare models
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('RF', RandomForestClassifier()))
models.append(('SVM', SVC(gamma='auto')))
models.append(('XGB', XGBClassifier()))

# evaluate each model in turn
results = []
names = []
scoring = 'recall'

for name, model in models:
        kfold = KFold(n_splits=10, random_state=None)
        cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring=scoring)
        results.append(cv_results)
        names.append(name)
        msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
        print(msg)
        
# boxplot algorithm comparison
fig = plt.figure(figsize=(11,6))
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# c:\Users\Samee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Samee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Samee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Samee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Samee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Samee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Samee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Samee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Samee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\Users\Samee\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LR: 0.341855 (0.051708)
# LDA: 0.416507 (0.075036)
# KNN: 0.209892 (0.072367)
# CART: 0.515018 (0.162331)
# NB: 0.586741 (0.083040)
# RF: 0.360189 (0.099824)
# SVM: 0.000000 (0.000000)
# XGB: 0.470382 (0.121081)

# %%
#Seting the Hyper Parameters
param_grid = {"max_depth": [3,5, 7, 10,None],
              "n_estimators":[3,5,10,25,50,150],
              "max_features": [4,7,15,20]}

#Creating the classifier
model = RandomForestClassifier(random_state=2)

grid_search = GridSearchCV(model, param_grid=param_grid, cv=5, scoring='recall', verbose=4)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# [CV 1/5] END max_depth=3, max_features=4, n_estimators
total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=15, n_estimators=25;, score=0.457 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=15, n_estimators=50;, score=0.333 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=15, n_estimators=50;, score=0.467 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=15, n_estimators=50;, score=0.435 total time=   0.1s
# [CV 4/5] END max_depth=None, max_features=15, n_estimators=50;, score=0.435 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=15, n_estimators=50;, score=0.478 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=15, n_estimators=150;, score=0.378 total time=   0.2s
# [CV 2/5] END max_depth=None, max_features=15, n_estimators=150;, score=0.400 total time=   0.2s
# [CV 3/5] END max_depth=None, max_features=15, n_estimators=150;, score=0.457 total time=   0.2s
# [CV 4/5] END max_depth=None, max_features=15, n_estimators=150;, score=0.413 total time=   0.2s
# [CV 5/5] END max_depth=None, max_features=15, n_estimators=150;, score=0.478 total time=   0.2s
# [CV 1/5] END max_depth=None, max_features=20, n_estimators=3;, score=0.400 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=20, n_estimators=3;, score=0.467 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=20, n_estimators=3;, score=0.500 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=20, n_estimators=3;, score=0.348 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=20, n_estimators=3;, score=0.435 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=20, n_estimators=5;, score=0.489 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=20, n_estimators=5;, score=0.511 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=20, n_estimators=5;, score=0.478 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=20, n_estimators=5;, score=0.326 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=20, n_estimators=5;, score=0.609 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=20, n_estimators=10;, score=0.311 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=20, n_estimators=10;, score=0.400 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=20, n_estimators=10;, score=0.348 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=20, n_estimators=10;, score=0.304 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=20, n_estimators=10;, score=0.435 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=20, n_estimators=25;, score=0.444 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=20, n_estimators=25;, score=0.400 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=20, n_estimators=25;, score=0.435 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=20, n_estimators=25;, score=0.391 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=20, n_estimators=25;, score=0.543 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=20, n_estimators=50;, score=0.378 total time=   0.0s
# [CV 2/5] END max_depth=None, max_features=20, n_estimators=50;, score=0.356 total time=   0.0s
# [CV 3/5] END max_depth=None, max_features=20, n_estimators=50;, score=0.370 total time=   0.0s
# [CV 4/5] END max_depth=None, max_features=20, n_estimators=50;, score=0.348 total time=   0.0s
# [CV 5/5] END max_depth=None, max_features=20, n_estimators=50;, score=0.478 total time=   0.0s
# [CV 1/5] END max_depth=None, max_features=20, n_estimators=150;, score=0.378 total time=   0.3s
# [CV 2/5] END max_depth=None, max_features=20, n_estimators=150;, score=0.444 total time=   0.2s
# [CV 3/5] END max_depth=None, max_features=20, n_estimators=150;, score=0.435 total time=   0.3s
# [CV 4/5] END max_depth=None, max_features=20, n_estimators=150;, score=0.413 total time=   0.3s
# [CV 5/5] END max_depth=None, max_features=20, n_estimators=150;, score=0.478 total time=   0.3s
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=2),
#              param_grid={'max_depth': [3, 5, 7, 10, None],
#                          'max_features': [4, 7, 15, 20],
#                          'n_estimators': [3, 5, 10, 25, 50, 150]},
#              scoring='recall', verbose=4)

# %%
print(grid_search.best_score_)
print(grid_search.best_params_)
# Out:
# 0.48714975845410624
# {'max_depth': None, 'max_features': 15, 'n_estimators': 3}

# %%
rf = RandomForestClassifier(max_depth=None, max_features=10, n_estimators=15, random_state=2)

#trainning with the best params
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_features=10, n_estimators=15, random_state=2)

# %%
#Testing the model 
#Predicting using our  model
y_pred = rf.predict(X_test)

# Verificaar os resultados obtidos
print(accuracy_score(y_test,y_pred))
print("\n")
print(confusion_matrix(y_test, y_pred))
print("\n")
print(fbeta_score(y_test, y_pred, beta=2))
# Out:
# 0.744
#
#
# [[159  19]
#  [ 45  27]]
#
#
# 0.4041916167664671

# %% [markdown]
# Model 2

# %%
from sklearn.utils import resample
from sklearn.metrics import roc_curve

# Criando o classificador logreg
GNB = GaussianNB()

# Fitting with train data
model = GNB.fit(X_train, y_train)

# Printing the Training Score
print("Training score data: ")
print(model.score(X_train, y_train))

y_pred = model.predict(X_test)

print(accuracy_score(y_test,y_pred))
print("\n")
print(confusion_matrix(y_test, y_pred))
print("\n")
print(classification_report(y_test, y_pred))

#Predicting proba
y_pred_prob = model.predict_proba(X_test)[:,1]

# Generate ROC curve values: fpr, tpr, thresholds
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Plot ROC curve
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()
# Out:
# Training score data:
# 0.7293333333333333
# 0.652
#
#
# [[129  49]
#  [ 38  34]]
#
#
#               precision    recall  f1-score   support
#
#        False       0.77      0.72      0.75       178
#         True       0.41      0.47      0.44        72
#
#     accuracy                           0.65       250
#    macro avg       0.59      0.60      0.59       250
# weighted avg       0.67      0.65      0.66       250
