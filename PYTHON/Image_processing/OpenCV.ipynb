# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import cv2

# %%
from glob import glob

# %%
graphs=glob("../Data_Science/graph_images/*.png")

# %%
mpl=plt.imread(graphs[5])
cv2=cv2.imread(graphs[5])

# %%
mpl.shape.cv2.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 mpl.shape.cv2.shape
#
# AttributeError: 'tuple' object has no attribute 'cv2'

# %%
plt.imshow(mpl) # showing the image
